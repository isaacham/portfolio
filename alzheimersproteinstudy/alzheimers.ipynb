# %%
# Importing Libraries

import pandas as pd
from chembl_webresource_client.new_client import new_client
import os

# %%
# Editing directory

cwd = os.getcwd()
print(cwd)

output = "/Users/admin/Desktop/Repositories/notebooks/bioinformatics/alzheimers/data"
os.chdir(output)
print(f"New Working Directory: {os.getcwd()}")
# Out:
# /Users/admin/Desktop/Repositories/notebooks/bioinformatics/alzheimers
# New Working Directory: /Users/admin/Desktop/Repositories/notebooks/bioinformatics/alzheimers/data

# %%
# Target search for HH (Hereditary Hemochromatosis)

target = new_client.target
target_query = target.search('alzheimers')
targets = pd.DataFrame.from_dict(target_query)

targets
# Out:
#                                     cross_references           organism  \
# 0                                                 []       Homo sapiens
# 1  [{'xref_id': 'Q92542', 'xref_name': None, 'xre...       Homo sapiens
# 2                                                 []       Homo sapiens
# 3                                                 []  Rattus norvegicus
# 4                                                 []       Mus musculus
# 5  [{'xref_id': 'P05067', 'xref_name': None, 'xre...       Homo sapiens
#
#                                    pref_name  score  species_group_flag  \
# 0  Nucleosome-remodeling factor subunit BPTF    6.0               False
# 1                                  Nicastrin    5.0               False
# 2                            Gamma-secretase    5.0               False
# 3                    Amyloid-beta A4 protein    4.0               False
# 4                    Amyloid-beta A4 protein    4.0               False
# 5                    Amyloid-beta A4 protein    3.0               False
#
#   target_chembl_id                                  target_components  \
# 0    CHEMBL3085621  [{'accession': 'Q12830', 'component_descriptio...
# 1       CHEMBL3418  [{'accession': 'Q92542', 'component_descriptio...
# 2    CHEMBL2094135  [{'accession': 'Q96BI3', 'component_descriptio...
# 3    CHEMBL3638365  [{'accession': 'P08592', 'component_descriptio...
# 4    CHEMBL4523942  [{'accession': 'P12023', 'component_descriptio...
# 5       CHEMBL2487  [{'accession': 'P05067', 'component_descriptio...
#
#        target_type  tax_id
# 0   SINGLE PROTEIN    9606
# 1   SINGLE PROTEIN    9606
# 2  PROTEIN COMPLEX    9606
# 3   SINGLE PROTEIN   10116
# 4   SINGLE PROTEIN   10090
# 5   SINGLE PROTEIN    9606

# %%
 # Select and Retrieve Bioactivity data for Alzheimers

selected_target = targets.target_chembl_id[5]
selected_target
# Out:
# 'CHEMBL2487'

# %%
# We will retrieve bioactivity data for amyloid-beta protein

activity = new_client.activity 
res = activity.filter(target_chembl_id=selected_target).filter(standard_type = "Inhibition")

# %%
df = pd.DataFrame.from_dict(res)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df = pd.DataFrame.from_dict(res)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:1917, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1911     raise ValueError(
#    1912         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1913         f"Got '{orient}' instead"
#    1914     )
#    1916 if orient != "tight":
# -> 1917     return cls(data, index=index, columns=columns, dtype=dtype)
#    1918 else:
#    1919     realdata = data["data"]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:843, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     841         data = np.asarray(data)
#     842     else:
# --> 843         data = list(data)
#     844 if len(data) > 0:
#     845     if is_dataclass(data[0]):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/chembl_webresource_client/query_set.py:127, in QuerySet.__next__(self)
#     126 def __next__(self):
# --> 127     return self.next()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/chembl_webresource_client/query_set.py:115, in QuerySet.next(self)
#     113     self.chunk = self.query.get_page()
#     114 if not self.chunk or self.current_index >= len(self.chunk):
# --> 115     self.chunk = self.query.next_page()
#     116     if not self.chunk:
#     117         raise StopIteration
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/chembl_webresource_client/url_query.py:434, in UrlQuery.next_page(self)
#     432 start = self.start
#     433 self.current_index = int(start + self.limit * (self.current_page + 1))
# --> 434 return self.get_page()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/chembl_webresource_client/url_query.py:389, in UrlQuery.get_page(self)
#     387 data = self._prepare_url_params()
#     388 with self._get_session() as session:
# --> 389     res = session.post(self.base_url + '.' + self.frmt, json=data, timeout=self.timeout)
#     390 self.logger.info(res.url)
#     391 self.logger.info(data)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests_cache/session.py:138, in CacheMixin.post(self, url, data, **kwargs)
#     137 def post(self, url: str, data=None, **kwargs) -> AnyResponse:  # type: ignore
# --> 138     return self.request('POST', url, data=data, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests_cache/session.py:183, in CacheMixin.request(self, method, url, headers, expire_after, only_if_cached, refresh, force_refresh, *args, **kwargs)
#     181 headers = set_request_headers(headers, expire_after, only_if_cached, refresh, force_refresh)
#     182 with patch_form_boundary() if kwargs.get('files') else nullcontext():
# --> 183     return super().request(method, url, *args, headers=headers, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests_cache/session.py:230, in CacheMixin.send(self, request, expire_after, only_if_cached, refresh, force_refresh, **kwargs)
#     228     response = self._resend(request, actions, cached_response, **kwargs)  # type: ignore
#     229 elif actions.send_request:
# --> 230     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#     231 else:
#     232     response = cached_response  # type: ignore  # Guaranteed to be non-None by this point
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests_cache/session.py:254, in CacheMixin._send_and_cache(self, request, actions, cached_response, **kwargs)
#     250 """Send a request and cache the response, unless disabled by settings or headers.
#     251 If applicable, also handle conditional requests.
#     252 """
#     253 request = actions.update_request(request)
# --> 254 response = super().send(request, **kwargs)
#     255 actions.update_from_response(response)
#     257 if not actions.skip_write:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df
# Out:
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# ..                                                ...              ...
# 93  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 94  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 95  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 96  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 97  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#     activity_id                                activity_properties  \
# 0       1431473                                                 []
# 1       1431474                                                 []
# 2       1431475                                                 []
# 3       1431476                                                 []
# 4       1431477                                                 []
# ..          ...                                                ...
# 93     24780126  [{'comments': None, 'relation': '=', 'result_f...
# 94     24780127  [{'comments': None, 'relation': '=', 'result_f...
# 95     25011084                                                 []
# 96     25011085                                                 []
# 97     25011086                                                 []
#
#    assay_chembl_id                                  assay_description  \
# 0     CHEMBL829743  In vitro effective concentration against beta ...
# 1     CHEMBL829742  In vitro effective concentration against beta ...
# 2     CHEMBL829743  In vitro effective concentration against beta ...
# 3     CHEMBL832682  In vitro inhibition of amyloid precursor prote...
# 4     CHEMBL825230  In vitro reduction of Swedish NL mutant amyloi...
# ..             ...                                                ...
# 93   CHEMBL5129305  Inhibition of amyloid beta 1 to 42 aggregation...
# 94   CHEMBL5129305  Inhibition of amyloid beta 1 to 42 aggregation...
# 95   CHEMBL5236698  Inhibition of amyloid beta 42 in human HEK293 ...
# 96   CHEMBL5236698  Inhibition of amyloid beta 42 in human HEK293 ...
# 97   CHEMBL5236699    Inhibition of amyloid beta 42 in human H4 cells
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000188
# 1           B                    None                   None  BAO_0000188
# 2           B                    None                   None  BAO_0000188
# 3           F                    None                   None  BAO_0000188
# 4           F                    None                   None  BAO_0000188
# ..        ...                     ...                    ...          ...
# 93          B                    None                   None  BAO_0000188
# 94          B                    None                   None  BAO_0000188
# 95          B                    None                   None  BAO_0000188
# 96          B                    None                   None  BAO_0000188
# 97          B                    None                   None  BAO_0000188
#
#     ... target_organism         target_pref_name target_tax_id text_value  \
# 0   ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1   ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 2   ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 3   ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 4   ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# ..  ...             ...                      ...           ...        ...
# 93  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 94  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 95  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 96  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 97  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
#
#     toid  type    units    uo_units upper_value value
# 0   None  EC50       uM  UO_0000065        None   0.1
# 1   None  EC50       uM  UO_0000065        None   3.5
# 2   None  EC50       uM  UO_0000065        None   5.0
# 3   None  EC50       uM  UO_0000065        None  1.03
# 4   None  EC50       uM  UO_0000065        None  0.53
# ..   ...   ...      ...         ...         ...   ...
# 93  None  EC50  ug ml-1  UO_0000274        None   8.9
# 94  None  EC50  ug ml-1  UO_0000274        None  10.0
# 95  None  EC50       uM  UO_0000065        None  0.27
# 96  None  EC50       uM  UO_0000065        None  0.07
# 97  None  EC50       uM  UO_0000065        None  0.07
#
# [98 rows x 46 columns]

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
# Handling missing data

df2 = df[df.standard_value.notna()]
df2
# Out:
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# ..                                                ...              ...
# 93  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 94  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 95  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 96  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 97  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#     activity_id                                activity_properties  \
# 0       1431473                                                 []
# 1       1431474                                                 []
# 2       1431475                                                 []
# 3       1431476                                                 []
# 4       1431477                                                 []
# ..          ...                                                ...
# 93     24780126  [{'comments': None, 'relation': '=', 'result_f...
# 94     24780127  [{'comments': None, 'relation': '=', 'result_f...
# 95     25011084                                                 []
# 96     25011085                                                 []
# 97     25011086                                                 []
#
#    assay_chembl_id                                  assay_description  \
# 0     CHEMBL829743  In vitro effective concentration against beta ...
# 1     CHEMBL829742  In vitro effective concentration against beta ...
# 2     CHEMBL829743  In vitro effective concentration against beta ...
# 3     CHEMBL832682  In vitro inhibition of amyloid precursor prote...
# 4     CHEMBL825230  In vitro reduction of Swedish NL mutant amyloi...
# ..             ...                                                ...
# 93   CHEMBL5129305  Inhibition of amyloid beta 1 to 42 aggregation...
# 94   CHEMBL5129305  Inhibition of amyloid beta 1 to 42 aggregation...
# 95   CHEMBL5236698  Inhibition of amyloid beta 42 in human HEK293 ...
# 96   CHEMBL5236698  Inhibition of amyloid beta 42 in human HEK293 ...
# 97   CHEMBL5236699    Inhibition of amyloid beta 42 in human H4 cells
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000188
# 1           B                    None                   None  BAO_0000188
# 2           B                    None                   None  BAO_0000188
# 3           F                    None                   None  BAO_0000188
# 4           F                    None                   None  BAO_0000188
# ..        ...                     ...                    ...          ...
# 93          B                    None                   None  BAO_0000188
# 94          B                    None                   None  BAO_0000188
# 95          B                    None                   None  BAO_0000188
# 96          B                    None                   None  BAO_0000188
# 97          B                    None                   None  BAO_0000188
#
#     ... target_organism         target_pref_name target_tax_id text_value  \
# 0   ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1   ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 2   ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 3   ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 4   ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# ..  ...             ...                      ...           ...        ...
# 93  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 94  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 95  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 96  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 97  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
#
#     toid  type    units    uo_units upper_value value
# 0   None  EC50       uM  UO_0000065        None   0.1
# 1   None  EC50       uM  UO_0000065        None   3.5
# 2   None  EC50       uM  UO_0000065        None   5.0
# 3   None  EC50       uM  UO_0000065        None  1.03
# 4   None  EC50       uM  UO_0000065        None  0.53
# ..   ...   ...      ...         ...         ...   ...
# 93  None  EC50  ug ml-1  UO_0000274        None   8.9
# 94  None  EC50  ug ml-1  UO_0000274        None  10.0
# 95  None  EC50       uM  UO_0000065        None  0.27
# 96  None  EC50       uM  UO_0000065        None  0.07
# 97  None  EC50       uM  UO_0000065        None  0.07
#
# [92 rows x 46 columns]

# %%
# Data preprocessing

bioactivity_class = []

for i in df2.standard_value:
    if float(i) >= 10000:
        bioactivity_class.append('inactive')
    elif float(i) <= 10000:
        bioactivity_class.append('active')
    else:
        bioactivity_class.append('intermediate')
        
# Iteration over mol_cid, canonical smiles, standard value

mol_cid = []
for i in df2.molecule_chembl_id:
    mol_cid.append(i)

canonical_smiles = []
for i in df2.molecule_chembl_id:
    canonical_smiles.append(i)

standard_value = []
for i in df2.molecule_chembl_id:
    standard_value.append(i)

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection] # Storing Data Selections into a dataframe
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL181204  CCCNC(=O)OC[C@@H](C)N(c1cc(Cl)ccc1CO)S(=O)(=O)...
# 1        CHEMBL360473  CCOC(=O)N1CCC(c2ccccc2OC)(S(=O)(=O)c2ccc(Cl)cc...
# 2        CHEMBL360473  CCOC(=O)N1CCC(c2ccccc2OC)(S(=O)(=O)c2ccc(Cl)cc...
# 3        CHEMBL360473  CCOC(=O)N1CCC(c2ccccc2OC)(S(=O)(=O)c2ccc(Cl)cc...
# 4        CHEMBL360473  CCOC(=O)N1CCC(c2ccccc2OC)(S(=O)(=O)c2ccc(Cl)cc...
# ..                ...                                                ...
# 93       CHEMBL449392  O=C(O[C@@H]1O[C@@H]2COC(=O)c3cc(O)c(O)c(O)c3-c...
# 94       CHEMBL506069  O=C1O[C@H]2[C@@H]3OC(=O)c4cc(O)c(O)c(O)c4-c4c(...
# 95      CHEMBL2151086  CC(C)CC(C(=O)O)c1cc(Cl)c(OCC2CC2)c(-c2ccc3nonc...
# 96      CHEMBL2151085  CC(C)CC(C(=O)O)c1cc(Cl)c(OCC2CC2)c(-c2ccc(C(F)...
# 97      CHEMBL3609747  O=C(O)[C@H](CC1CCC1)c1cc(Cl)c(OCC(F)(F)F)c(-c2...
#
#    standard_value
# 0           100.0
# 1          3500.0
# 2          5000.0
# 3          1030.0
# 4           530.0
# ..            ...
# 93            8.9
# 94           10.0
# 95          270.0
# 96           70.0
# 97           70.0
#
# [92 rows x 3 columns]

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)

# Handling missing data

df4 = df4[df4.standard_value.notna()]
df4
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL181204  CCCNC(=O)OC[C@@H](C)N(c1cc(Cl)ccc1CO)S(=O)(=O)...
# 1        CHEMBL360473  CCOC(=O)N1CCC(c2ccccc2OC)(S(=O)(=O)c2ccc(Cl)cc...
# 2        CHEMBL360473  CCOC(=O)N1CCC(c2ccccc2OC)(S(=O)(=O)c2ccc(Cl)cc...
# 3        CHEMBL360473  CCOC(=O)N1CCC(c2ccccc2OC)(S(=O)(=O)c2ccc(Cl)cc...
# 4        CHEMBL360473  CCOC(=O)N1CCC(c2ccccc2OC)(S(=O)(=O)c2ccc(Cl)cc...
# ..                ...                                                ...
# 93       CHEMBL449392  O=C(O[C@@H]1O[C@@H]2COC(=O)c3cc(O)c(O)c(O)c3-c...
# 94       CHEMBL506069  O=C1O[C@H]2[C@@H]3OC(=O)c4cc(O)c(O)c(O)c4-c4c(...
# 95      CHEMBL2151086  CC(C)CC(C(=O)O)c1cc(Cl)c(OCC2CC2)c(-c2ccc3nonc...
# 96      CHEMBL2151085  CC(C)CC(C(=O)O)c1cc(Cl)c(OCC2CC2)c(-c2ccc(C(F)...
# 97      CHEMBL3609747  O=C(O)[C@H](CC1CCC1)c1cc(Cl)c(OCC(F)(F)F)c(-c2...
#
#    standard_value bioactivity_class
# 0           100.0            active
# 1          3500.0            active
# 2          5000.0            active
# 3          1030.0            active
# 4           530.0            active
# ..            ...               ...
# 93            8.9               NaN
# 94           10.0               NaN
# 95          270.0               NaN
# 96           70.0               NaN
# 97           70.0               NaN
#
# [92 rows x 4 columns]

# %%
# Save DataFrame into a .csv file

df4.to_csv('bioactivity_preprocessed_data.csv', index=False)
